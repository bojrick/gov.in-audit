# %%
from utils import list_r2_files, fetch_supabase_table

r2_files = list_r2_files()
supabase_data = fetch_supabase_table('websites_report_tracking')

# %%
supabase_data
# Out:
#                                        id  \
# 0    65e1a762-8c18-4468-8630-81119c15935b
# 1    b5c129de-7933-485c-b501-935cd519e644
# 2    e6265bab-6848-4df4-9392-7b74a69be466
# 3    98ed850a-2cbe-406c-a1d9-eb823bb67113
# 4    7d47bd98-5cbf-41e0-a30c-00025d2a001d
# ..                                    ...
# 995  d4e0e394-31ad-4ce0-9c2e-8c8a023184c5
# 996  cec58042-7b4c-4f26-949b-c558d717a223
# 997  9900c5b0-acc6-4521-bd7c-df6ceafd7056
# 998  3530085c-963c-4bfd-80a3-09ee41420ce0
# 999  e84929fa-235a-4292-84ba-41b49ba5206e
#
#                                                 url     status  \
# 0                              https://www.kship.in  completed
# 1               https://sppanchmahal.gujarat.gov.in  completed
# 2                    https://maharashtrasrpf.gov.in  completed
# 3                  https://chittoorpolice.ap.gov.in  completed
# 4                               https://srfti.ac.in  completed
# ..                                              ...        ...
# ...

# %%
r2_files.head()
# Out:
#                                                  Key     Size  \
# 0  govin-audit-reports/lighthouse-reports/html/00...  1138562
# 1  govin-audit-reports/lighthouse-reports/html/00...   722113
# 2  govin-audit-reports/lighthouse-reports/html/00...   617986
# 3  govin-audit-reports/lighthouse-reports/html/00...   875630
# 4  govin-audit-reports/lighthouse-reports/html/00...   902735
#
#                       LastModified  \
# 0 2024-10-21 03:38:24.602000+00:00
# 1 2024-10-22 01:41:47.201000+00:00
# 2 2024-10-22 00:32:14.256000+00:00
# 3 2024-10-20 23:28:44.535000+00:00
# 4 2024-10-22 00:13:49.175000+00:00
#
#                                                 path
# 0  https://govin-audit-reports.r2.cloudflarestora...
# 1  https://govin-audit-reports.r2.cloudflarestora...
# 2  https://govin-audit-reports.r2.cloudflarestora...
# 3  https://govin-audit-reports.r2.cloudflarestora...
# 4  https://govin-audit-reports.r2.cloudflarestora...
